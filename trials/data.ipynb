# %% [markdown]
# Understanding how to use statsbombpy

# %%
from statsbombpy import sb
import pandas as pd

# %%
sb.competitions()
# Out:
# /Users/leesol/Library/Python/3.9/lib/python/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     competition_id  season_id               country_name
# 0                9         27                    Germany  \
# 1               16          4                     Europe
# 2               16          1                     Europe
# 3               16          2                     Europe
# 4               16         27                     Europe
# 5               16         26                     Europe
# 6               16         25                     Europe
# 7               16         24                     Europe
# 8               16         23                     Europe
# 9               16         22                     Europe
# 10              16         21                     Europe
# 11              16         41                     Europe
# ...

# %%
sb.matches(competition_id=16, season_id=2)
# Out:
# /Users/leesol/Library/Python/3.9/lib/python/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#    match_id  match_date      kick_off                competition     season
# 0     18244  2017-06-03  20:45:00.000  Europe - Champions League  2016/2017  \
#
#   home_team    away_team  home_score  away_score match_status
# 0  Juventus  Real Madrid           1           4    available  \
#
#   match_status_360      last_updated         last_updated_360  match_week
# 0        scheduled  2020-07-29T05:00  2021-06-13T16:17:31.694           7  \
#
#   competition_stage               stadium      referee         home_managers
# 0             Final  Principality Stadium  Felix Brych  Massimiliano Allegri  \
#
#      away_managers data_version shot_fidelity_version xy_fidelity_version
# 0  Zinédine Zidane        1.0.3                  None                None

# %%
pd.set_option('display.max_rows', 10)

sb.lineups(match_id=18244)["Real Madrid"]
# Out:
# /Users/leesol/Library/Python/3.9/lib/python/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     player_id                      player_name  player_nickname
# 0        3063             Danilo Luiz da Silva           Danilo  \
# 1        3477       Álvaro Borja Morata Martín    Álvaro Morata
# 2        4926   Francisco Román Alarcón Suárez             Isco
# 3        5201              Sergio Ramos García     Sergio Ramos
# 4        5202  José Ignacio Fernández Iglesias            Nacho
# ..        ...                              ...              ...
# 13       5719          Marco Asensio Willemsen             None
# 14       5721            Daniel Carvajal Ramos  Daniel Carvajal
# 15       6399                Gareth Frank Bale      Gareth Bale
# 16       6706         Francisco Casilla Cortés     Kiko Casilla
# 17      19677                    Karim Benzema             None
#
# ...

# %%
df = sb.events(match_id=18244, split=True, flatten_attrs=False)["passes"]
#df = sb.events(match_id=18244, include_360_metrics=True)
rma_df = df[df['team'] == "Real Madrid"]
rma_df.head()
# Out:
# /Users/leesol/Library/Python/3.9/lib/python/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#                                       id  index  period     timestamp  minute
# 4   cb0a7bf8-cc46-428f-b364-8b4a706638f7     17       1  00:00:20.152       0  \
# 5   bde2c55d-923d-4528-b3a4-857f526289d7     20       1  00:00:21.002       0
# 18  3a17c781-6513-4554-bd20-878713228eb0     56       1  00:00:53.755       0
# 19  aa3b43bb-53f4-4029-9729-313758fbf31a     65       1  00:01:20.359       1
# 20  fd4f8c6e-181a-408c-94e5-82b7fb69c08b     67       1  00:01:23.505       1
#
#     second  type  possession possession_team    play_pattern         team
# 4       20  Pass           3        Juventus   From Throw In  Real Madrid  \
# 5       21  Pass           3        Juventus   From Throw In  Real Madrid
# 18      53  Pass           4     Real Madrid    Regular Play  Real Madrid
# ...
